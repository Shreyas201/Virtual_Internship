# %%
http://localhost:8888/edit/server3.py
# Out:
#   File "<ipython-input-1-ecb853080d2c>", line 1
#     http://localhost:8888/edit/server3.py
#           ^
# SyntaxError: invalid syntax

# %%
import urllib.request
import time
import json
import random

# %%
# Server API URLs
QUERY = "http://localhost:8080/query?id={}"

# %%
# 500 server request
N = 500

# %%
def getDataPoint(quote):
	""" Produce all of the needed values to generate a datapoint """
	""" ------------- Update this function ------------- """
	stock = quote['stock']
	bid_price = float(quote['top_bid']['price'])
	ask_price = float(quote['top_ask']['price'])
	price = (bid_price+ask_price)/2
	return stock, bid_price, ask_price, price

# %%
def getRatio(price_a, price_b):
	""" Get ratio of price_a and price_b """
	""" ------------- Update this function ------------- """
	""" Also create some unit tests for this function in client_test.py """
	return price_a/price_b

# %%
# Main
if __name__ == "__main__":

	# Query the price once every N seconds.
	for _ in iter(range(N)):
		quotes = json.loads(urllib.request.urlopen(QUERY.format(random.random())).read())

		""" ----------- Update to get the ratio --------------- """
		prices = {}        
		for quote in quotes:
			stock, bid_price, ask_price, price = getDataPoint(quote)
			prices[stock] = price            
			print ("Quoted %s at (bid:%s, ask:%s, price:%s)" % (stock, bid_price, ask_price, price))
		print ("Ratio %s" % (getRatio(prices['ABC'], prices['DEF'])))
# Out:
# Quoted ABC at (bid:122.9, ask:122.59, price:122.745)
# Quoted DEF at (bid:123.18, ask:122.71, price:122.945)
# Ratio 0.9983732563341332
# Quoted ABC at (bid:122.9, ask:122.59, price:122.745)
# Quoted DEF at (bid:123.18, ask:122.71, price:122.945)
# Ratio 0.9983732563341332
# Quoted ABC at (bid:121.55, ask:122.59, price:122.07)
# Quoted DEF at (bid:122.32, ask:122.71, price:122.51499999999999)
# Ratio 0.9963677916989757
# Quoted ABC at (bid:121.55, ask:122.59, price:122.07)
# Quoted DEF at (bid:122.32, ask:122.71, price:122.51499999999999)
# Ratio 0.9963677916989757
# Quoted ABC at (bid:121.55, ask:122.59, price:122.07)
# Quoted DEF at (bid:122.32, ask:122.71, price:122.51499999999999)
# Ratio 0.9963677916989757
# Quoted ABC at (bid:121.55, ask:122.59, price:122.07)
# Quoted DEF at (bid:121.74, ask:122.71, price:122.225)
# Ratio 0.9987318470034772
# Quoted ABC at (bid:121.55, ask:121.33, price:121.44)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 1.004092769440655
# Quoted ABC at (bid:121.55, ask:121.33, price:121.44)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 1.004092769440655
# Quoted ABC at (bid:121.55, ask:121.33, price:121.44)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 1.004092769440655
# Quoted ABC at (bid:121.55, ask:121.33, price:121.44)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 1.004092769440655
# Quoted ABC at (bid:121.55, ask:119.58, price:120.565)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 0.9968580759849519
# Quoted ABC at (bid:121.55, ask:119.58, price:120.565)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 0.9968580759849519
# Quoted ABC at (bid:121.55, ask:119.58, price:120.565)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 0.9968580759849519
# Quoted ABC at (bid:121.55, ask:119.58, price:120.565)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 0.9968580759849519
# Quoted ABC at (bid:121.55, ask:119.58, price:120.565)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 0.9968580759849519
# Quoted ABC at (bid:121.55, ask:119.58, price:120.565)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 0.9968580759849519
# Quoted ABC at (bid:121.55, ask:119.58, price:120.565)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 0.9968580759849519
# Quoted ABC at (bid:121.55, ask:119.58, price:120.565)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 0.9968580759849519
# Quoted ABC at (bid:121.55, ask:119.58, price:120.565)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 0.9968580759849519
# Quoted ABC at (bid:120.25, ask:119.58, price:119.91499999999999)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 0.991483732275001
# Quoted ABC at (bid:120.25, ask:119.58, price:119.91499999999999)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 0.991483732275001
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 1.003596676175121
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:121.74, ask:120.15, price:120.945)
# Ratio 1.003596676175121
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:121.74, ask:121.91, price:121.82499999999999)
# Ratio 0.9963472193720502
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:121.74, ask:121.91, price:121.82499999999999)
# Ratio 0.9963472193720502
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:121.74, ask:123.11, price:122.425)
# Ratio 0.9914641617316724
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:123.23, ask:122.71, price:122.97)
# Ratio 0.9870700170773359
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:123.23, ask:122.71, price:122.97)
# Ratio 0.9870700170773359
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:123.23, ask:122.71, price:122.97)
# Ratio 0.9870700170773359
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:123.23, ask:122.71, price:122.97)
# Ratio 0.9870700170773359
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:123.23, ask:122.71, price:122.97)
# Ratio 0.9870700170773359
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:123.23, ask:122.71, price:122.97)
# Ratio 0.9870700170773359
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:123.23, ask:122.71, price:122.97)
# Ratio 0.9870700170773359
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:123.23, ask:122.71, price:122.97)
# Ratio 0.9870700170773359
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:123.23, ask:122.71, price:122.97)
# Ratio 0.9870700170773359
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:123.23, ask:123.11, price:123.17)
# Ratio 0.9854672403994479
# Quoted ABC at (bid:121.71, ask:121.65, price:121.68)
# Quoted DEF at (bid:123.23, ask:123.11, price:123.17)
# Ratio 0.98790289843306
# Quoted ABC at (bid:121.71, ask:121.65, price:121.68)
# Quoted DEF at (bid:123.23, ask:123.11, price:123.17)
# Ratio 0.98790289843306
# Quoted ABC at (bid:121.71, ask:121.65, price:121.68)
# Quoted DEF at (bid:123.23, ask:123.11, price:123.17)
# Ratio 0.98790289843306
# Quoted ABC at (bid:121.71, ask:121.65, price:121.68)
# Quoted DEF at (bid:123.23, ask:123.11, price:123.17)
# Ratio 0.98790289843306
# Quoted ABC at (bid:121.71, ask:121.65, price:121.68)
# Quoted DEF at (bid:123.23, ask:123.11, price:123.17)
# Ratio 0.98790289843306
# Quoted ABC at (bid:121.71, ask:121.65, price:121.68)
# Quoted DEF at (bid:123.23, ask:123.11, price:123.17)
# Ratio 0.98790289843306
# Quoted ABC at (bid:121.71, ask:121.65, price:121.68)
# Quoted DEF at (bid:123.23, ask:123.11, price:123.17)
# Ratio 0.98790289843306
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:120.03, ask:123.11, price:121.57)
# Ratio 0.998437114419676
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:120.03, ask:123.11, price:121.57)
# Ratio 0.998437114419676
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:120.03, ask:123.11, price:121.57)
# Ratio 0.998437114419676
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:120.03, ask:123.11, price:121.57)
# Ratio 0.998437114419676
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:119.8, ask:123.11, price:121.455)
# Ratio 0.9993824873409904
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:119.8, ask:123.11, price:121.455)
# Ratio 0.9993824873409904
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:119.8, ask:123.11, price:121.455)
# Ratio 0.9993824873409904
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:119.8, ask:123.11, price:121.455)
# Ratio 0.9993824873409904
# Quoted ABC at (bid:121.11, ask:121.65, price:121.38)
# Quoted DEF at (bid:119.8, ask:123.11, price:121.455)
# Ratio 0.9993824873409904
# Quoted ABC at (bid:120.83, ask:118.35, price:119.59)
# Quoted DEF at (bid:119.8, ask:118.91, price:119.35499999999999)
# Ratio 1.0019689162582215
# Quoted ABC at (bid:120.83, ask:118.35, price:119.59)
# Quoted DEF at (bid:119.8, ask:118.91, price:119.35499999999999)
# Ratio 1.0019689162582215
# Quoted ABC at (bid:120.76, ask:118.35, price:119.555)
# Quoted DEF at (bid:119.8, ask:118.91, price:119.35499999999999)
# Ratio 1.0016756734112522
# Quoted ABC at (bid:120.76, ask:118.35, price:119.555)
# Quoted DEF at (bid:119.8, ask:118.91, price:119.35499999999999)
# Ratio 1.0016756734112522
# Quoted ABC at (bid:120.76, ask:118.35, price:119.555)
# Quoted DEF at (bid:116.78, ask:118.01, price:117.39500000000001)
# Ratio 1.0183994207589762
# Quoted ABC at (bid:120.76, ask:118.35, price:119.555)
# Quoted DEF at (bid:116.78, ask:114.4, price:115.59)
# Ratio 1.034302275283329
# Quoted ABC at (bid:120.76, ask:118.35, price:119.555)
# Quoted DEF at (bid:116.78, ask:114.4, price:115.59)
# Ratio 1.034302275283329
# Quoted ABC at (bid:118.92, ask:118.35, price:118.63499999999999)
# Quoted DEF at (bid:116.78, ask:114.4, price:115.59)
# Ratio 1.0263431092655073
# Quoted ABC at (bid:118.92, ask:118.35, price:118.63499999999999)
# Quoted DEF at (bid:116.78, ask:114.4, price:115.59)
# Ratio 1.0263431092655073
# Quoted ABC at (bid:118.92, ask:115.54, price:117.23)
# Quoted DEF at (bid:116.78, ask:114.4, price:115.59)
# Ratio 1.014188078553508
# Quoted ABC at (bid:118.92, ask:115.54, price:117.23)
# Quoted DEF at (bid:116.78, ask:114.4, price:115.59)
# Ratio 1.014188078553508
# Quoted ABC at (bid:118.92, ask:115.54, price:117.23)
# Quoted DEF at (bid:116.78, ask:114.24, price:115.50999999999999)
# Ratio 1.0148904856722363
# Quoted ABC at (bid:118.92, ask:115.54, price:117.23)
# Quoted DEF at (bid:114.1, ask:114.24, price:114.16999999999999)
# Ratio 1.0268021371638785
# Quoted ABC at (bid:118.92, ask:115.54, price:117.23)
# Quoted DEF at (bid:114.1, ask:114.24, price:114.16999999999999)
# Ratio 1.0268021371638785
# Quoted ABC at (bid:118.92, ask:113.51, price:116.215)
# Quoted DEF at (bid:114.1, ask:114.24, price:114.16999999999999)
# Ratio 1.0179118857843568
# Quoted ABC at (bid:118.39, ask:118.35, price:118.37)
# Quoted DEF at (bid:114.1, ask:114.24, price:114.16999999999999)
# Ratio 1.0367872470876764
# Quoted ABC at (bid:118.39, ask:118.35, price:118.37)
# Quoted DEF at (bid:114.1, ask:114.24, price:114.16999999999999)
# Ratio 1.0367872470876764
# Quoted ABC at (bid:118.39, ask:118.35, price:118.37)
# Quoted DEF at (bid:114.1, ask:114.24, price:114.16999999999999)
# Ratio 1.0367872470876764
# Quoted ABC at (bid:118.39, ask:118.35, price:118.37)
# Quoted DEF at (bid:114.1, ask:114.24, price:114.16999999999999)
# Ratio 1.0367872470876764
# Quoted ABC at (bid:115.23, ask:113.51, price:114.37)
# Quoted DEF at (bid:114.1, ask:109.88, price:111.99)
# Ratio 1.0212518974908475
# Quoted ABC at (bid:115.23, ask:113.51, price:114.37)
# Quoted DEF at (bid:114.1, ask:109.88, price:111.99)
# Ratio 1.0212518974908475
# Quoted ABC at (bid:112.95, ask:113.51, price:113.23)
# Quoted DEF at (bid:114.1, ask:107.29, price:110.695)
# Ratio 1.0229007633587788
# Quoted ABC at (bid:112.95, ask:113.51, price:113.23)
# Quoted DEF at (bid:114.1, ask:107.29, price:110.695)
# Ratio 1.0229007633587788
# Quoted ABC at (bid:112.95, ask:113.51, price:113.23)
# Quoted DEF at (bid:114.1, ask:107.29, price:110.695)
# Ratio 1.0229007633587788
# Quoted ABC at (bid:112.95, ask:113.51, price:113.23)
# Quoted DEF at (bid:111.0, ask:107.29, price:109.14500000000001)
# Ratio 1.0374272756424938
# Quoted ABC at (bid:112.95, ask:113.51, price:113.23)
# Quoted DEF at (bid:111.0, ask:107.29, price:109.14500000000001)
# Ratio 1.0374272756424938
# Quoted ABC at (bid:112.95, ask:113.51, price:113.23)
# Quoted DEF at (bid:111.0, ask:107.29, price:109.14500000000001)
# Ratio 1.0374272756424938
# Quoted ABC at (bid:112.95, ask:109.53, price:111.24000000000001)
# Quoted DEF at (bid:111.0, ask:107.29, price:109.14500000000001)
# Ratio 1.0191946493197124
# Quoted ABC at (bid:112.51, ask:109.53, price:111.02000000000001)
# Quoted DEF at (bid:111.0, ask:107.29, price:109.14500000000001)
# Ratio 1.017178982088048
# Quoted ABC at (bid:112.51, ask:109.53, price:111.02000000000001)
# Quoted DEF at (bid:111.0, ask:107.29, price:109.14500000000001)
# Ratio 1.017178982088048
# Quoted ABC at (bid:112.51, ask:109.53, price:111.02000000000001)
# Quoted DEF at (bid:109.96, ask:110.58, price:110.27)
# Ratio 1.0068014872585473
# Quoted ABC at (bid:112.51, ask:109.53, price:111.02000000000001)
# Quoted DEF at (bid:109.96, ask:110.58, price:110.27)
# Ratio 1.0068014872585473
# Quoted ABC at (bid:112.51, ask:109.53, price:111.02000000000001)
# Quoted DEF at (bid:109.96, ask:110.58, price:110.27)
# Ratio 1.0068014872585473
# Quoted ABC at (bid:112.51, ask:109.53, price:111.02000000000001)
# Quoted DEF at (bid:109.96, ask:110.58, price:110.27)
# Ratio 1.0068014872585473
# Quoted ABC at (bid:108.94, ask:109.53, price:109.235)
# Quoted DEF at (bid:109.96, ask:109.88, price:109.91999999999999)
# Ratio 0.9937681950509463
# Quoted ABC at (bid:108.94, ask:109.53, price:109.235)
# Quoted DEF at (bid:109.96, ask:109.88, price:109.91999999999999)
# Ratio 0.9937681950509463
# Quoted ABC at (bid:108.94, ask:109.53, price:109.235)
# Quoted DEF at (bid:108.82, ask:107.29, price:108.055)
# Ratio 1.010920364629124
# Quoted ABC at (bid:108.94, ask:109.39, price:109.16499999999999)
# Quoted DEF at (bid:107.27, ask:107.29, price:107.28)
# Ratio 1.0175708426547352
# Quoted ABC at (bid:108.94, ask:109.39, price:109.16499999999999)
# Quoted DEF at (bid:107.27, ask:107.29, price:107.28)
# Ratio 1.0175708426547352
# Quoted ABC at (bid:108.94, ask:109.39, price:109.16499999999999)
# Quoted DEF at (bid:107.27, ask:104.32, price:105.79499999999999)
# Ratio 1.0318540573751123
# Quoted ABC at (bid:108.94, ask:109.39, price:109.16499999999999)
# Quoted DEF at (bid:104.42, ask:105.75, price:105.08500000000001)
# Ratio 1.0388257125184372
# Quoted ABC at (bid:108.94, ask:109.39, price:109.16499999999999)
# Quoted DEF at (bid:104.42, ask:105.75, price:105.08500000000001)
# Ratio 1.0388257125184372
# Quoted ABC at (bid:108.94, ask:109.39, price:109.16499999999999)
# Quoted DEF at (bid:104.42, ask:105.75, price:105.08500000000001)
# Ratio 1.0388257125184372
# Quoted ABC at (bid:108.94, ask:109.39, price:109.16499999999999)
# Quoted DEF at (bid:104.42, ask:104.32, price:104.37)
# Ratio 1.0459423205902079
# Quoted ABC at (bid:107.78, ask:109.39, price:108.58500000000001)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.0410335075020374
# Quoted ABC at (bid:107.78, ask:109.39, price:108.58500000000001)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.0410335075020374
# Quoted ABC at (bid:107.78, ask:109.36, price:108.57)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.040889698480418
# Quoted ABC at (bid:107.78, ask:109.36, price:108.57)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.040889698480418
# Quoted ABC at (bid:107.78, ask:109.36, price:108.57)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.040889698480418
# Quoted ABC at (bid:107.78, ask:109.36, price:108.57)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.040889698480418
# Quoted ABC at (bid:107.78, ask:109.36, price:108.57)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.040889698480418
# Quoted ABC at (bid:107.78, ask:109.36, price:108.57)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.040889698480418
# Quoted ABC at (bid:105.48, ask:106.76, price:106.12)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.017400891615934
# Quoted ABC at (bid:105.48, ask:106.76, price:106.12)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.017400891615934
# Quoted ABC at (bid:105.48, ask:106.76, price:106.12)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.017400891615934
# Quoted ABC at (bid:106.75, ask:106.76, price:106.755)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.0234888068644838
# Quoted ABC at (bid:106.75, ask:106.76, price:106.755)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.0234888068644838
# Quoted ABC at (bid:106.75, ask:106.76, price:106.755)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.0234888068644838
# Quoted ABC at (bid:106.75, ask:106.76, price:106.755)
# Quoted DEF at (bid:104.29, ask:104.32, price:104.305)
# Ratio 1.0234888068644838
# Quoted ABC at (bid:106.75, ask:106.76, price:106.755)
# Quoted DEF at (bid:104.01, ask:104.32, price:104.16499999999999)
# Ratio 1.0248643978303653
# Quoted ABC at (bid:107.73, ask:106.76, price:107.245)
# Quoted DEF at (bid:104.01, ask:104.32, price:104.16499999999999)
# Ratio 1.0295684730955696
# Quoted ABC at (bid:107.73, ask:109.36, price:108.545)
# Quoted DEF at (bid:104.01, ask:104.32, price:104.16499999999999)
# Ratio 1.0420486727787646
# Quoted ABC at (bid:107.73, ask:109.36, price:108.545)
# Quoted DEF at (bid:104.01, ask:104.32, price:104.16499999999999)
# Ratio 1.0420486727787646
# Quoted ABC at (bid:107.73, ask:109.36, price:108.545)
# Quoted DEF at (bid:104.01, ask:104.32, price:104.16499999999999)
# Ratio 1.0420486727787646
# Quoted ABC at (bid:107.73, ask:109.36, price:108.545)
# Quoted DEF at (bid:104.01, ask:104.32, price:104.16499999999999)
# Ratio 1.0420486727787646
# Quoted ABC at (bid:107.73, ask:109.36, price:108.545)
# Quoted DEF at (bid:104.01, ask:104.32, price:104.16499999999999)
# Ratio 1.0420486727787646
# Quoted ABC at (bid:107.73, ask:109.36, price:108.545)
# Quoted DEF at (bid:104.01, ask:104.84, price:104.42500000000001)
# Ratio 1.0394541536988269
# Quoted ABC at (bid:107.73, ask:108.96, price:108.345)
# Quoted DEF at (bid:104.84, ask:104.32, price:104.58)
# Ratio 1.0360011474469306
# Quoted ABC at (bid:107.73, ask:108.96, price:108.345)
# Quoted DEF at (bid:104.84, ask:104.32, price:104.58)
# Ratio 1.0360011474469306
# Quoted ABC at (bid:107.73, ask:108.96, price:108.345)
# Quoted DEF at (bid:104.84, ask:104.84, price:104.84)
# Ratio 1.0334318962228157
# Quoted ABC at (bid:108.92, ask:108.96, price:108.94)
# Quoted DEF at (bid:104.84, ask:104.84, price:104.84)
# Ratio 1.0391072109881725
# Quoted ABC at (bid:108.92, ask:108.96, price:108.94)
# Quoted DEF at (bid:104.84, ask:104.84, price:104.84)
# Ratio 1.0391072109881725
# Quoted ABC at (bid:108.92, ask:108.96, price:108.94)
# Quoted DEF at (bid:105.35, ask:104.32, price:104.835)
# Ratio 1.0391567701626365
# Quoted ABC at (bid:108.92, ask:108.96, price:108.94)
# Quoted DEF at (bid:106.38, ask:104.32, price:105.35)
# Ratio 1.034076886568581
# Quoted ABC at (bid:108.92, ask:108.96, price:108.94)
# Quoted DEF at (bid:106.38, ask:104.32, price:105.35)
# Ratio 1.034076886568581
# Quoted ABC at (bid:108.92, ask:108.96, price:108.94)
# Quoted DEF at (bid:106.38, ask:104.32, price:105.35)
# Ratio 1.034076886568581
# Quoted ABC at (bid:108.92, ask:109.36, price:109.14)
# Quoted DEF at (bid:106.38, ask:104.32, price:105.35)
# Ratio 1.0359753203607025
# Quoted ABC at (bid:108.92, ask:109.36, price:109.14)
# Quoted DEF at (bid:106.38, ask:104.32, price:105.35)
# Ratio 1.0359753203607025
# Quoted ABC at (bid:108.92, ask:109.39, price:109.155)
# Quoted DEF at (bid:106.38, ask:105.75, price:106.065)
# Ratio 1.0291330787724509
# Quoted ABC at (bid:108.92, ask:109.39, price:109.155)
# Quoted DEF at (bid:106.38, ask:105.75, price:106.065)
# Ratio 1.0291330787724509
# Quoted ABC at (bid:108.92, ask:109.39, price:109.155)
# Quoted DEF at (bid:106.69, ask:107.11, price:106.9)
# Ratio 1.0210944808231992
# Quoted ABC at (bid:108.92, ask:109.39, price:109.155)
# Quoted DEF at (bid:106.69, ask:107.11, price:106.9)
# Ratio 1.0210944808231992
# Quoted ABC at (bid:109.44, ask:109.53, price:109.485)
# Quoted DEF at (bid:108.12, ask:107.11, price:107.61500000000001)
# Ratio 1.0173767597453887
# Quoted ABC at (bid:113.76, ask:113.1, price:113.43)
# Quoted DEF at (bid:108.12, ask:107.11, price:107.61500000000001)
# Ratio 1.0540352181387354
# Quoted ABC at (bid:113.76, ask:108.96, price:111.36)
# Quoted DEF at (bid:108.12, ask:107.11, price:107.61500000000001)
# Ratio 1.0347999814152302
# Quoted ABC at (bid:113.76, ask:108.96, price:111.36)
# Quoted DEF at (bid:108.12, ask:107.11, price:107.61500000000001)
# Ratio 1.0347999814152302
# Quoted ABC at (bid:113.76, ask:108.96, price:111.36)
# Quoted DEF at (bid:108.12, ask:107.11, price:107.61500000000001)
# Ratio 1.0347999814152302
# Quoted ABC at (bid:113.76, ask:108.96, price:111.36)
# Quoted DEF at (bid:110.26, ask:107.11, price:108.685)
# Ratio 1.0246124120163775
# Quoted ABC at (bid:113.76, ask:112.87, price:113.315)
# Quoted DEF at (bid:110.26, ask:107.11, price:108.685)
# Ratio 1.042600174817132
# Quoted ABC at (bid:113.76, ask:112.87, price:113.315)
# Quoted DEF at (bid:110.26, ask:107.11, price:108.685)
# Ratio 1.042600174817132
# Quoted ABC at (bid:113.76, ask:112.87, price:113.315)
# Quoted DEF at (bid:111.19, ask:107.11, price:109.15)
# Ratio 1.0381584974805314
# Quoted ABC at (bid:113.76, ask:112.87, price:113.315)
# Quoted DEF at (bid:111.19, ask:114.4, price:112.795)
# Ratio 1.0046101334279
# Quoted ABC at (bid:113.76, ask:113.1, price:113.43)
# Quoted DEF at (bid:111.19, ask:114.4, price:112.795)
# Ratio 1.0056296821667627
# Quoted ABC at (bid:113.76, ask:113.1, price:113.43)
# Quoted DEF at (bid:111.19, ask:114.4, price:112.795)
# Ratio 1.0056296821667627
# Quoted ABC at (bid:114.09, ask:108.96, price:111.525)
# Quoted DEF at (bid:113.76, ask:114.4, price:114.08000000000001)
# Ratio 0.9776034361851332
# Quoted ABC at (bid:114.3, ask:113.1, price:113.69999999999999)
# Quoted DEF at (bid:113.76, ask:114.4, price:114.08000000000001)
# Ratio 0.9966690042075734
# Quoted ABC at (bid:114.51, ask:113.1, price:113.805)
# Quoted DEF at (bid:113.76, ask:114.4, price:114.08000000000001)
# Ratio 0.9975894109396914
# Quoted ABC at (bid:114.51, ask:113.1, price:113.805)
# Quoted DEF at (bid:113.76, ask:114.4, price:114.08000000000001)
# Ratio 0.9975894109396914
# Quoted ABC at (bid:114.51, ask:113.1, price:113.805)
# Quoted DEF at (bid:113.76, ask:114.4, price:114.08000000000001)
# Ratio 0.9975894109396914
# Quoted ABC at (bid:115.36, ask:113.1, price:114.22999999999999)
# Quoted DEF at (bid:115.4, ask:115.52, price:115.46000000000001)
# Ratio 0.9893469599861422
# Quoted ABC at (bid:115.36, ask:113.1, price:114.22999999999999)
# Quoted DEF at (bid:115.4, ask:115.52, price:115.46000000000001)
# Ratio 0.9893469599861422
# Quoted ABC at (bid:115.56, ask:108.96, price:112.25999999999999)
# Quoted DEF at (bid:115.4, ask:115.52, price:115.46000000000001)
# Ratio 0.9722847739476874
# Quoted ABC at (bid:115.56, ask:113.1, price:114.33)
# Quoted DEF at (bid:115.4, ask:115.52, price:115.46000000000001)
# Ratio 0.990213060800277
# Quoted ABC at (bid:115.71, ask:115.87, price:115.78999999999999)
# Quoted DEF at (bid:115.4, ask:115.52, price:115.46000000000001)
# Ratio 1.0028581326866446
# Quoted ABC at (bid:115.71, ask:115.87, price:115.78999999999999)
# Quoted DEF at (bid:115.4, ask:115.52, price:115.46000000000001)
# Ratio 1.0028581326866446
# Quoted ABC at (bid:115.71, ask:115.87, price:115.78999999999999)
# Quoted DEF at (bid:115.4, ask:115.52, price:115.46000000000001)
# Ratio 1.0028581326866446
# Quoted ABC at (bid:115.71, ask:115.87, price:115.78999999999999)
# Quoted DEF at (bid:115.4, ask:115.52, price:115.46000000000001)
# Ratio 1.0028581326866446
# Quoted ABC at (bid:115.71, ask:115.87, price:115.78999999999999)
# Quoted DEF at (bid:115.4, ask:115.52, price:115.46000000000001)
# Ratio 1.0028581326866446
# Quoted ABC at (bid:115.71, ask:115.87, price:115.78999999999999)
# Quoted DEF at (bid:115.4, ask:115.52, price:115.46000000000001)
# Ratio 1.0028581326866446
# Quoted ABC at (bid:115.83, ask:115.87, price:115.85)
# Quoted DEF at (bid:115.4, ask:115.52, price:115.46000000000001)
# Ratio 1.0033777931751255
# Quoted ABC at (bid:115.83, ask:115.87, price:115.85)
# Quoted DEF at (bid:115.4, ask:115.52, price:115.46000000000001)
# Ratio 1.0033777931751255
# Quoted ABC at (bid:115.83, ask:115.87, price:115.85)
# Quoted DEF at (bid:115.4, ask:115.52, price:115.46000000000001)
# Ratio 1.0033777931751255
# Quoted ABC at (bid:115.83, ask:115.87, price:115.85)
# Quoted DEF at (bid:115.4, ask:115.52, price:115.46000000000001)
# Ratio 1.0033777931751255
# Quoted ABC at (bid:116.42, ask:116.85, price:116.63499999999999)
# Quoted DEF at (bid:116.2, ask:115.52, price:115.86)
# Ratio 1.006689107543587
# Quoted ABC at (bid:116.42, ask:116.85, price:116.63499999999999)
# Quoted DEF at (bid:116.2, ask:115.52, price:115.86)
# Ratio 1.006689107543587
# Quoted ABC at (bid:116.91, ask:115.87, price:116.39)
# Quoted DEF at (bid:116.2, ask:115.52, price:115.86)
# Ratio 1.0045744864491628
# Quoted ABC at (bid:116.91, ask:115.87, price:116.39)
# Quoted DEF at (bid:116.2, ask:115.52, price:115.86)
# Ratio 1.0045744864491628
# Quoted ABC at (bid:116.91, ask:115.87, price:116.39)
# Quoted DEF at (bid:116.57, ask:115.52, price:116.04499999999999)
# Ratio 1.0029729846180362
# Quoted ABC at (bid:116.91, ask:115.87, price:116.39)
# Quoted DEF at (bid:116.57, ask:116.42, price:116.495)
# Ratio 0.9990986737628224
# Quoted ABC at (bid:116.91, ask:115.87, price:116.39)
# Quoted DEF at (bid:116.57, ask:116.42, price:116.495)
# Ratio 0.9990986737628224
# Quoted ABC at (bid:116.91, ask:116.85, price:116.88)
# Quoted DEF at (bid:116.57, ask:116.42, price:116.495)
# Ratio 1.003304862869651
# Quoted ABC at (bid:116.91, ask:116.85, price:116.88)
# Quoted DEF at (bid:116.57, ask:116.42, price:116.495)
# Ratio 1.003304862869651
# Quoted ABC at (bid:117.38, ask:116.07, price:116.725)
# Quoted DEF at (bid:116.83, ask:115.52, price:116.175)
# Ratio 1.0047342371422423
# Quoted ABC at (bid:117.38, ask:116.07, price:116.725)
# Quoted DEF at (bid:116.83, ask:115.52, price:116.175)
# Ratio 1.0047342371422423
# Quoted ABC at (bid:117.38, ask:116.07, price:116.725)
# Quoted DEF at (bid:116.83, ask:117.0, price:116.91499999999999)
# Ratio 0.9983748877389557
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:116.83, ask:117.0, price:116.91499999999999)
# Ratio 0.9955950904503272
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:116.83, ask:117.0, price:116.91499999999999)
# Ratio 0.9955950904503272
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:116.83, ask:117.0, price:116.91499999999999)
# Ratio 0.9955950904503272
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:116.57, ask:116.02, price:116.29499999999999)
# Ratio 1.0009028763059462
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:117.5, ask:117.0, price:117.25)
# Ratio 0.9927505330490406
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:117.5, ask:117.0, price:117.25)
# Ratio 0.9927505330490406
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:116.83, ask:116.9, price:116.86500000000001)
# Ratio 0.9960210499294057
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:116.83, ask:116.9, price:116.86500000000001)
# Ratio 0.9960210499294057
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:116.83, ask:116.9, price:116.86500000000001)
# Ratio 0.9960210499294057
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:116.83, ask:116.9, price:116.86500000000001)
# Ratio 0.9960210499294057
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:116.83, ask:116.9, price:116.86500000000001)
# Ratio 0.9960210499294057
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:116.83, ask:116.02, price:116.425)
# Ratio 0.9997852694867941
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:116.83, ask:116.02, price:116.425)
# Ratio 0.9997852694867941
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:116.83, ask:116.02, price:116.425)
# Ratio 0.9997852694867941
# Quoted ABC at (bid:117.1, ask:115.7, price:116.4)
# Quoted DEF at (bid:116.57, ask:115.3, price:115.935)
# Ratio 1.0040108681588822
# Quoted ABC at (bid:116.91, ask:115.7, price:116.305)
# Quoted DEF at (bid:116.57, ask:115.3, price:115.935)
# Ratio 1.003191443481261
# Quoted ABC at (bid:116.91, ask:115.7, price:116.305)
# Quoted DEF at (bid:116.57, ask:115.3, price:115.935)
# Ratio 1.003191443481261
# Quoted ABC at (bid:116.91, ask:115.7, price:116.305)
# Quoted DEF at (bid:116.57, ask:114.74, price:115.655)
# Ratio 1.0056201634170594
# Quoted ABC at (bid:116.91, ask:115.7, price:116.305)
# Quoted DEF at (bid:113.81, ask:115.3, price:114.555)
# Ratio 1.0152765047357164
# Quoted ABC at (bid:116.91, ask:115.7, price:116.305)
# Quoted DEF at (bid:113.81, ask:115.3, price:114.555)
# Ratio 1.0152765047357164
# Quoted ABC at (bid:116.91, ask:115.7, price:116.305)
# Quoted DEF at (bid:114.0, ask:115.3, price:114.65)
# Ratio 1.0144352376798953
# Quoted ABC at (bid:116.91, ask:115.7, price:116.305)
# Quoted DEF at (bid:114.0, ask:115.3, price:114.65)
# Ratio 1.0144352376798953
# Quoted ABC at (bid:116.91, ask:115.7, price:116.305)
# Quoted DEF at (bid:114.0, ask:115.3, price:114.65)
# Ratio 1.0144352376798953
# Quoted ABC at (bid:116.91, ask:115.7, price:116.305)
# Quoted DEF at (bid:114.0, ask:115.3, price:114.65)
# Ratio 1.0144352376798953
# Quoted ABC at (bid:116.91, ask:115.7, price:116.305)
# Quoted DEF at (bid:114.0, ask:114.74, price:114.37)
# Ratio 1.016918772405351
# Quoted ABC at (bid:115.47, ask:115.7, price:115.58500000000001)
# Quoted DEF at (bid:114.0, ask:114.74, price:114.37)
# Ratio 1.010623415231267
# Quoted ABC at (bid:115.47, ask:115.7, price:115.58500000000001)
# Quoted DEF at (bid:114.0, ask:114.74, price:114.37)
# Ratio 1.010623415231267
# Quoted ABC at (bid:115.47, ask:115.7, price:115.58500000000001)
# Quoted DEF at (bid:114.52, ask:114.74, price:114.63)
# Ratio 1.008331152403385
# Quoted ABC at (bid:115.47, ask:115.7, price:115.58500000000001)
# Quoted DEF at (bid:114.52, ask:114.74, price:114.63)
# Ratio 1.008331152403385
# Quoted ABC at (bid:115.47, ask:115.7, price:115.58500000000001)
# Quoted DEF at (bid:114.52, ask:114.74, price:114.63)
# Ratio 1.008331152403385
# Quoted ABC at (bid:115.47, ask:115.7, price:115.58500000000001)
# Quoted DEF at (bid:114.52, ask:113.98, price:114.25)
# Ratio 1.0116849015317286
# Quoted ABC at (bid:115.47, ask:115.7, price:115.58500000000001)
# Quoted DEF at (bid:114.52, ask:113.98, price:114.25)
# Ratio 1.0116849015317286
# Quoted ABC at (bid:113.87, ask:115.7, price:114.785)
# Quoted DEF at (bid:114.52, ask:113.98, price:114.25)
# Ratio 1.0046827133479213
# Quoted ABC at (bid:113.87, ask:115.7, price:114.785)
# Quoted DEF at (bid:114.52, ask:113.98, price:114.25)
# Ratio 1.0046827133479213
# Quoted ABC at (bid:113.87, ask:115.33, price:114.6)
# Quoted DEF at (bid:114.52, ask:113.98, price:114.25)
# Ratio 1.0030634573304158
# Quoted ABC at (bid:113.87, ask:115.33, price:114.6)
# Quoted DEF at (bid:114.52, ask:113.98, price:114.25)
# Ratio 1.0030634573304158
# Quoted ABC at (bid:113.87, ask:113.99, price:113.93)
# Quoted DEF at (bid:114.0, ask:113.98, price:113.99000000000001)
# Ratio 0.9994736380384244
# Quoted ABC at (bid:113.66, ask:112.95, price:113.305)
# Quoted DEF at (bid:114.0, ask:113.98, price:113.99000000000001)
# Ratio 0.9939907009386788
# Quoted ABC at (bid:113.66, ask:112.95, price:113.305)
# Quoted DEF at (bid:114.0, ask:113.98, price:113.99000000000001)
# Ratio 0.9939907009386788
# Quoted ABC at (bid:113.51, ask:112.95, price:113.23)
# Quoted DEF at (bid:114.0, ask:113.98, price:113.99000000000001)
# Ratio 0.9933327484867093
# Quoted ABC at (bid:113.51, ask:112.95, price:113.23)
# Quoted DEF at (bid:114.0, ask:113.98, price:113.99000000000001)
# Ratio 0.9933327484867093
# Quoted ABC at (bid:113.51, ask:112.95, price:113.23)
# Quoted DEF at (bid:113.81, ask:113.98, price:113.89500000000001)
# Ratio 0.9941612889064488
# Quoted ABC at (bid:113.51, ask:112.95, price:113.23)
# Quoted DEF at (bid:113.81, ask:113.98, price:113.89500000000001)
# Ratio 0.9941612889064488
# Quoted ABC at (bid:113.23, ask:112.95, price:113.09)
# Quoted DEF at (bid:113.81, ask:113.98, price:113.89500000000001)
# Ratio 0.9929320865709644
# Quoted ABC at (bid:113.23, ask:112.95, price:113.09)
# Quoted DEF at (bid:113.81, ask:113.98, price:113.89500000000001)
# Ratio 0.9929320865709644
# Quoted ABC at (bid:113.23, ask:112.95, price:113.09)
# Quoted DEF at (bid:113.81, ask:113.98, price:113.89500000000001)
# Ratio 0.9929320865709644
# Quoted ABC at (bid:113.23, ask:112.95, price:113.09)
# Quoted DEF at (bid:113.81, ask:113.98, price:113.89500000000001)
# Ratio 0.9929320865709644
# Quoted ABC at (bid:113.23, ask:112.95, price:113.09)
# Quoted DEF at (bid:113.66, ask:113.98, price:113.82)
# Ratio 0.993586364435073
# Quoted ABC at (bid:113.23, ask:112.95, price:113.09)
# Quoted DEF at (bid:113.66, ask:113.98, price:113.82)
# Ratio 0.993586364435073
# Quoted ABC at (bid:113.23, ask:110.3, price:111.765)
# Quoted DEF at (bid:113.66, ask:113.98, price:113.82)
# Ratio 0.9819451765946231
# Quoted ABC at (bid:113.23, ask:110.3, price:111.765)
# Quoted DEF at (bid:113.66, ask:113.98, price:113.82)
# Ratio 0.9819451765946231
# Quoted ABC at (bid:113.23, ask:110.3, price:111.765)
# Quoted DEF at (bid:113.66, ask:113.98, price:113.82)
# Ratio 0.9819451765946231
# Quoted ABC at (bid:113.23, ask:110.3, price:111.765)
# Quoted DEF at (bid:113.66, ask:113.98, price:113.82)
# Ratio 0.9819451765946231
# Quoted ABC at (bid:112.73, ask:112.95, price:112.84)
# Quoted DEF at (bid:113.66, ask:113.29, price:113.475)
# Ratio 0.9944040537563341
# Quoted ABC at (bid:112.73, ask:112.95, price:112.84)
# Quoted DEF at (bid:113.66, ask:113.29, price:113.475)
# Ratio 0.9944040537563341
# Quoted ABC at (bid:112.73, ask:112.95, price:112.84)
# Quoted DEF at (bid:113.66, ask:113.29, price:113.475)
# Ratio 0.9944040537563341
# Quoted ABC at (bid:110.96, ask:106.57, price:108.76499999999999)
# Quoted DEF at (bid:113.66, ask:113.29, price:113.475)
# Ratio 0.9584930601454064
# Quoted ABC at (bid:108.33, ask:110.3, price:109.315)
# Quoted DEF at (bid:113.66, ask:113.29, price:113.475)
# Ratio 0.9633399427186605
# Quoted ABC at (bid:108.33, ask:110.3, price:109.315)
# Quoted DEF at (bid:113.66, ask:113.29, price:113.475)
# Ratio 0.9633399427186605
# Quoted ABC at (bid:107.63, ask:107.65, price:107.64)
# Quoted DEF at (bid:113.66, ask:105.32, price:109.49)
# Ratio 0.983103479769842
# Quoted ABC at (bid:107.63, ask:107.65, price:107.64)
# Quoted DEF at (bid:113.66, ask:105.32, price:109.49)
# Ratio 0.983103479769842
# Quoted ABC at (bid:107.63, ask:107.65, price:107.64)
# Quoted DEF at (bid:113.66, ask:105.32, price:109.49)
# Ratio 0.983103479769842
# Quoted ABC at (bid:107.63, ask:107.65, price:107.64)
# Quoted DEF at (bid:112.77, ask:113.29, price:113.03)
# Ratio 0.9523135450765283
# Quoted ABC at (bid:107.63, ask:107.65, price:107.64)
# Quoted DEF at (bid:112.77, ask:113.29, price:113.03)
# Ratio 0.9523135450765283
# Quoted ABC at (bid:107.63, ask:106.91, price:107.27)
# Quoted DEF at (bid:110.62, ask:107.47, price:109.045)
# Ratio 0.9837223164748498
# Quoted ABC at (bid:107.63, ask:106.91, price:107.27)
# Quoted DEF at (bid:110.62, ask:107.47, price:109.045)
# Ratio 0.9837223164748498
# Quoted ABC at (bid:106.03, ask:106.91, price:106.47)
# Quoted DEF at (bid:107.35, ask:107.47, price:107.41)
# Ratio 0.9912484871054836
# Quoted ABC at (bid:106.03, ask:106.91, price:106.47)
# Quoted DEF at (bid:107.35, ask:107.47, price:107.41)
# Ratio 0.9912484871054836
# Quoted ABC at (bid:106.03, ask:106.91, price:106.47)
# Quoted DEF at (bid:104.28, ask:106.61, price:105.445)
# Ratio 1.009720707477832
# Quoted ABC at (bid:106.03, ask:106.91, price:106.47)
# Quoted DEF at (bid:104.28, ask:106.61, price:105.445)
# Ratio 1.009720707477832
# Quoted ABC at (bid:106.03, ask:106.91, price:106.47)
# Quoted DEF at (bid:104.28, ask:105.32, price:104.8)
# Ratio 1.015935114503817
# Quoted ABC at (bid:106.03, ask:106.91, price:106.47)
# Quoted DEF at (bid:104.28, ask:103.42, price:103.85)
# Ratio 1.02522869523351
# Quoted ABC at (bid:106.03, ask:106.57, price:106.3)
# Quoted DEF at (bid:104.28, ask:103.42, price:103.85)
# Ratio 1.0235917188252288
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:104.28, ask:103.42, price:103.85)
# Ratio 1.0168030813673568
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:104.28, ask:103.42, price:103.85)
# Ratio 1.0168030813673568
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:104.28, ask:103.42, price:103.85)
# Ratio 1.0168030813673568
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:104.28, ask:103.42, price:103.85)
# Ratio 1.0168030813673568
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:103.64, ask:103.42, price:103.53)
# Ratio 1.019945909398242
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:103.64, ask:103.42, price:103.53)
# Ratio 1.019945909398242
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:103.64, ask:103.42, price:103.53)
# Ratio 1.019945909398242
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:103.64, ask:103.42, price:103.53)
# Ratio 1.019945909398242
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:104.01, ask:103.42, price:103.715)
# Ratio 1.0181265969242637
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:103.47, ask:103.42, price:103.445)
# Ratio 1.020783991493064
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:104.28, ask:105.2, price:104.74000000000001)
# Ratio 1.008163070460187
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:104.28, ask:105.2, price:104.74000000000001)
# Ratio 1.008163070460187
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:104.28, ask:105.2, price:104.74000000000001)
# Ratio 1.008163070460187
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:104.01, ask:105.2, price:104.605)
# Ratio 1.009464174752641
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:104.01, ask:105.2, price:104.605)
# Ratio 1.009464174752641
# Quoted ABC at (bid:105.09, ask:105.22, price:105.155)
# Quoted DEF at (bid:104.01, ask:105.2, price:104.605)
# Ratio 1.0052578748625782
# Quoted ABC at (bid:105.09, ask:105.22, price:105.155)
# Quoted DEF at (bid:104.01, ask:105.2, price:104.605)
# Ratio 1.0052578748625782
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:104.01, ask:105.2, price:104.605)
# Ratio 1.009464174752641
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:104.01, ask:105.2, price:104.605)
# Ratio 1.009464174752641
# Quoted ABC at (bid:106.03, ask:105.16, price:105.595)
# Quoted DEF at (bid:104.01, ask:105.2, price:104.605)
# Ratio 1.009464174752641
# Quoted ABC at (bid:106.62, ask:105.16, price:105.89)
# Quoted DEF at (bid:104.01, ask:105.2, price:104.605)
# Ratio 1.0122843076334782
# Quoted ABC at (bid:106.62, ask:105.16, price:105.89)
# Quoted DEF at (bid:104.01, ask:105.2, price:104.605)
# Ratio 1.0122843076334782
# Quoted ABC at (bid:106.62, ask:105.16, price:105.89)
# Quoted DEF at (bid:104.01, ask:105.2, price:104.605)
# Ratio 1.0122843076334782
# Quoted ABC at (bid:106.62, ask:105.16, price:105.89)
# Quoted DEF at (bid:104.01, ask:105.2, price:104.605)
# Ratio 1.0122843076334782
# Quoted ABC at (bid:106.62, ask:105.16, price:105.89)
# Quoted DEF at (bid:104.01, ask:105.2, price:104.605)
# Ratio 1.0122843076334782
# Quoted ABC at (bid:106.62, ask:105.16, price:105.89)
# Quoted DEF at (bid:104.01, ask:105.2, price:104.605)
# Ratio 1.0122843076334782
# Quoted ABC at (bid:106.62, ask:105.16, price:105.89)
# Quoted DEF at (bid:104.01, ask:105.2, price:104.605)
# Ratio 1.0122843076334782
# Quoted ABC at (bid:106.62, ask:105.16, price:105.89)
# Quoted DEF at (bid:105.45, ask:105.2, price:105.325)
# Ratio 1.0053643484452883
# Quoted ABC at (bid:106.62, ask:105.16, price:105.89)
# Quoted DEF at (bid:105.45, ask:105.2, price:105.325)
# Ratio 1.0053643484452883
# Quoted ABC at (bid:107.09, ask:105.16, price:106.125)
# Quoted DEF at (bid:105.45, ask:105.2, price:105.325)
# Ratio 1.0075955376216472
# Quoted ABC at (bid:107.09, ask:105.16, price:106.125)
# Quoted DEF at (bid:105.45, ask:105.2, price:105.325)
# Ratio 1.0075955376216472
# Quoted ABC at (bid:107.09, ask:105.16, price:106.125)
# Quoted DEF at (bid:105.45, ask:105.2, price:105.325)
# Ratio 1.0075955376216472
# Quoted ABC at (bid:107.09, ask:105.16, price:106.125)
# Quoted DEF at (bid:105.45, ask:105.2, price:105.325)
# Ratio 1.0075955376216472
# Quoted ABC at (bid:107.32, ask:104.79, price:106.055)
# Quoted DEF at (bid:106.42, ask:103.42, price:104.92)
# Ratio 1.010817765916889
# Quoted ABC at (bid:107.32, ask:104.79, price:106.055)
# Quoted DEF at (bid:106.42, ask:103.42, price:104.92)
# Ratio 1.010817765916889
# Quoted ABC at (bid:107.32, ask:104.79, price:106.055)
# Quoted DEF at (bid:106.42, ask:103.42, price:104.92)
# Ratio 1.010817765916889
# Quoted ABC at (bid:107.32, ask:104.79, price:106.055)
# Quoted DEF at (bid:106.42, ask:103.42, price:104.92)
# Ratio 1.010817765916889
# Quoted ABC at (bid:107.32, ask:104.79, price:106.055)
# Quoted DEF at (bid:106.42, ask:103.42, price:104.92)
# Ratio 1.010817765916889
# Quoted ABC at (bid:106.62, ask:106.42, price:106.52000000000001)
# Quoted DEF at (bid:106.42, ask:105.2, price:105.81)
# Ratio 1.0067101408184482
# Quoted ABC at (bid:106.62, ask:106.42, price:106.52000000000001)
# Quoted DEF at (bid:106.42, ask:105.2, price:105.81)
# Ratio 1.0067101408184482
# Quoted ABC at (bid:106.62, ask:106.42, price:106.52000000000001)
# Quoted DEF at (bid:106.42, ask:105.2, price:105.81)
# Ratio 1.0067101408184482
# Quoted ABC at (bid:106.62, ask:106.42, price:106.52000000000001)
# Quoted DEF at (bid:106.42, ask:105.2, price:105.81)
# Ratio 1.0067101408184482
# Quoted ABC at (bid:106.62, ask:106.42, price:106.52000000000001)
# Quoted DEF at (bid:106.42, ask:105.43, price:105.92500000000001)
# Ratio 1.005617181968374
# Quoted ABC at (bid:106.62, ask:106.42, price:106.52000000000001)
# Quoted DEF at (bid:105.45, ask:105.81, price:105.63)
# Ratio 1.0084256366562532
# Quoted ABC at (bid:106.07, ask:105.87, price:105.97)
# Quoted DEF at (bid:105.45, ask:105.81, price:105.63)
# Ratio 1.0032187825428382
# Quoted ABC at (bid:106.07, ask:105.87, price:105.97)
# Quoted DEF at (bid:105.45, ask:105.81, price:105.63)
# Ratio 1.0032187825428382
# Quoted ABC at (bid:106.07, ask:106.42, price:106.245)
# Quoted DEF at (bid:105.45, ask:105.81, price:105.63)
# Ratio 1.0058222095995457
# Quoted ABC at (bid:106.07, ask:106.42, price:106.245)
# Quoted DEF at (bid:105.45, ask:105.81, price:105.63)
# Ratio 1.0058222095995457
# Quoted ABC at (bid:106.07, ask:106.42, price:106.245)
# Quoted DEF at (bid:105.45, ask:105.81, price:105.63)
# Ratio 1.0058222095995457
# Quoted ABC at (bid:106.07, ask:106.42, price:106.245)
# Quoted DEF at (bid:105.45, ask:105.81, price:105.63)
# Ratio 1.0058222095995457
# Quoted ABC at (bid:106.07, ask:106.42, price:106.245)
# Quoted DEF at (bid:105.45, ask:105.53, price:105.49000000000001)
# Ratio 1.007157076500142
# Quoted ABC at (bid:105.09, ask:106.42, price:105.755)
# Quoted DEF at (bid:105.45, ask:105.53, price:105.49000000000001)
# Ratio 1.002512086453692
# Quoted ABC at (bid:105.09, ask:106.42, price:105.755)
# Quoted DEF at (bid:105.45, ask:105.53, price:105.49000000000001)
# Ratio 1.002512086453692
# Quoted ABC at (bid:105.09, ask:106.42, price:105.755)
# Quoted DEF at (bid:105.45, ask:105.53, price:105.49000000000001)
# Ratio 1.002512086453692
# Quoted ABC at (bid:105.09, ask:105.87, price:105.48)
# Quoted DEF at (bid:105.45, ask:105.43, price:105.44)
# Ratio 1.0003793626707134
# Quoted ABC at (bid:105.09, ask:106.18, price:105.635)
# Quoted DEF at (bid:105.45, ask:105.43, price:105.44)
# Ratio 1.001849393019727
# Quoted ABC at (bid:105.09, ask:106.18, price:105.635)
# Quoted DEF at (bid:105.45, ask:105.43, price:105.44)
# Ratio 1.001849393019727
# Quoted ABC at (bid:105.09, ask:106.18, price:105.635)
# Quoted DEF at (bid:105.45, ask:105.43, price:105.44)
# Ratio 1.001849393019727
# Quoted ABC at (bid:105.09, ask:106.18, price:105.635)
# Quoted DEF at (bid:105.45, ask:105.53, price:105.49000000000001)
# Ratio 1.0013745378708883
# Quoted ABC at (bid:105.09, ask:106.18, price:105.635)
# Quoted DEF at (bid:105.45, ask:105.53, price:105.49000000000001)
# Ratio 1.0013745378708883
# Quoted ABC at (bid:104.68, ask:106.18, price:105.43)
# Quoted DEF at (bid:105.45, ask:103.0, price:104.225)
# Ratio 1.0115615255456945
# Quoted ABC at (bid:104.68, ask:106.18, price:105.43)
# Quoted DEF at (bid:105.45, ask:103.0, price:104.225)
# Ratio 1.0115615255456945
# Quoted ABC at (bid:104.68, ask:106.18, price:105.43)
# Quoted DEF at (bid:104.02, ask:103.65, price:103.83500000000001)
# Ratio 1.015360909134685
# Quoted ABC at (bid:104.68, ask:106.18, price:105.43)
# Quoted DEF at (bid:104.02, ask:103.65, price:103.83500000000001)
# Ratio 1.015360909134685
# Quoted ABC at (bid:104.68, ask:105.87, price:105.275)
# Quoted DEF at (bid:105.45, ask:99.65, price:102.55000000000001)
# Ratio 1.0265724037055095
# Quoted ABC at (bid:104.68, ask:105.87, price:105.275)
# Quoted DEF at (bid:105.45, ask:99.65, price:102.55000000000001)
# Ratio 1.0265724037055095
# Quoted ABC at (bid:104.68, ask:105.87, price:105.275)
# Quoted DEF at (bid:104.02, ask:99.65, price:101.83500000000001)
# Ratio 1.0337801345313498
# Quoted ABC at (bid:104.68, ask:105.87, price:105.275)
# Quoted DEF at (bid:104.02, ask:99.65, price:101.83500000000001)
# Ratio 1.0337801345313498
# Quoted ABC at (bid:104.68, ask:105.87, price:105.275)
# Quoted DEF at (bid:104.02, ask:99.65, price:101.83500000000001)
# Ratio 1.0337801345313498
# Quoted ABC at (bid:104.68, ask:105.87, price:105.275)
# Quoted DEF at (bid:103.49, ask:103.0, price:103.245)
# Ratio 1.01966196910262
# Quoted ABC at (bid:104.68, ask:102.78, price:103.73)
# Quoted DEF at (bid:103.49, ask:103.0, price:103.245)
# Ratio 1.004697564046685
# Quoted ABC at (bid:104.68, ask:102.78, price:103.73)
# Quoted DEF at (bid:103.49, ask:103.0, price:103.245)
# Ratio 1.004697564046685
# Quoted ABC at (bid:104.68, ask:102.78, price:103.73)
# Quoted DEF at (bid:103.49, ask:103.0, price:103.245)
# Ratio 1.004697564046685
# Quoted ABC at (bid:100.23, ask:101.48, price:100.855)
# Quoted DEF at (bid:103.49, ask:103.0, price:103.245)
# Ratio 0.9768511792338612
# Quoted ABC at (bid:98.99, ask:99.86, price:99.425)
# Quoted DEF at (bid:103.49, ask:103.0, price:103.245)
# Ratio 0.9630006295704392
# Quoted ABC at (bid:98.99, ask:99.86, price:99.425)
# Quoted DEF at (bid:103.49, ask:103.0, price:103.245)
# Ratio 0.9630006295704392
# Quoted ABC at (bid:98.99, ask:99.86, price:99.425)
# Quoted DEF at (bid:103.49, ask:103.0, price:103.245)
# Ratio 0.9630006295704392
# Quoted ABC at (bid:98.99, ask:99.03, price:99.00999999999999)
# Quoted DEF at (bid:103.49, ask:103.0, price:103.245)
# Ratio 0.9589810644583272
# Quoted ABC at (bid:98.99, ask:99.03, price:99.00999999999999)
# Quoted DEF at (bid:103.49, ask:103.0, price:103.245)
# Ratio 0.9589810644583272
# Quoted ABC at (bid:98.99, ask:99.03, price:99.00999999999999)
# Quoted DEF at (bid:100.01, ask:102.2, price:101.105)
# Ratio 0.9792789674101181
# Quoted ABC at (bid:98.99, ask:99.03, price:99.00999999999999)
# Quoted DEF at (bid:100.01, ask:102.2, price:101.105)
# Ratio 0.9792789674101181
# Quoted ABC at (bid:97.83, ask:98.98, price:98.405)
# Quoted DEF at (bid:100.01, ask:102.2, price:101.105)
# Ratio 0.9732950892636368
# Quoted ABC at (bid:97.83, ask:98.98, price:98.405)
# Quoted DEF at (bid:100.01, ask:102.2, price:101.105)
# Ratio 0.9732950892636368
# Quoted ABC at (bid:97.83, ask:98.98, price:98.405)
# Quoted DEF at (bid:100.01, ask:102.2, price:101.105)
# Ratio 0.9732950892636368
# Quoted ABC at (bid:97.83, ask:98.77, price:98.3)
# Quoted DEF at (bid:100.01, ask:102.2, price:101.105)
# Ratio 0.9722565649572226
# Quoted ABC at (bid:97.83, ask:98.77, price:98.3)
# Quoted DEF at (bid:100.01, ask:102.2, price:101.105)
# Ratio 0.9722565649572226
# Quoted ABC at (bid:97.83, ask:98.77, price:98.3)
# Quoted DEF at (bid:100.01, ask:102.2, price:101.105)
# Ratio 0.9722565649572226
# Quoted ABC at (bid:97.83, ask:98.77, price:98.3)
# Quoted DEF at (bid:100.01, ask:102.2, price:101.105)
# Ratio 0.9722565649572226
# Quoted ABC at (bid:97.83, ask:98.77, price:98.3)
# Quoted DEF at (bid:100.01, ask:102.2, price:101.105)
# Ratio 0.9722565649572226
# Quoted ABC at (bid:97.83, ask:98.77, price:98.3)
# Quoted DEF at (bid:99.69, ask:99.72, price:99.705)
# Ratio 0.9859084298681109
# Quoted ABC at (bid:97.83, ask:98.77, price:98.3)
# Quoted DEF at (bid:99.69, ask:99.72, price:99.705)
# Ratio 0.9859084298681109
# Quoted ABC at (bid:97.83, ask:98.77, price:98.3)
# Quoted DEF at (bid:99.69, ask:99.72, price:99.705)
# Ratio 0.9859084298681109
# Quoted ABC at (bid:97.83, ask:98.77, price:98.3)
# Quoted DEF at (bid:99.69, ask:99.65, price:99.67)
# Ratio 0.986254640313033
# Quoted ABC at (bid:97.83, ask:97.82, price:97.82499999999999)
# Quoted DEF at (bid:99.69, ask:99.65, price:99.67)
# Ratio 0.9814889134142669
# Quoted ABC at (bid:97.83, ask:97.82, price:97.82499999999999)
# Quoted DEF at (bid:99.69, ask:99.65, price:99.67)
# Ratio 0.9814889134142669
# Quoted ABC at (bid:97.83, ask:97.82, price:97.82499999999999)
# Quoted DEF at (bid:98.89, ask:99.65, price:99.27000000000001)
# Ratio 0.9854437392968669
# Quoted ABC at (bid:97.83, ask:97.82, price:97.82499999999999)
# Quoted DEF at (bid:98.89, ask:99.65, price:99.27000000000001)
# Ratio 0.9854437392968669
# Quoted ABC at (bid:97.83, ask:97.82, price:97.82499999999999)
# Quoted DEF at (bid:98.89, ask:99.65, price:99.27000000000001)
# Ratio 0.9854437392968669
# Quoted ABC at (bid:97.83, ask:97.82, price:97.82499999999999)
# Quoted DEF at (bid:98.89, ask:99.65, price:99.27000000000001)
# Ratio 0.9854437392968669
# Quoted ABC at (bid:97.83, ask:97.82, price:97.82499999999999)
# Quoted DEF at (bid:98.89, ask:99.65, price:99.27000000000001)
# Ratio 0.9854437392968669
# Quoted ABC at (bid:97.83, ask:97.82, price:97.82499999999999)
# Quoted DEF at (bid:98.89, ask:99.65, price:99.27000000000001)
# Ratio 0.9854437392968669
# Quoted ABC at (bid:97.83, ask:97.82, price:97.82499999999999)
# Quoted DEF at (bid:98.89, ask:99.65, price:99.27000000000001)
# Ratio 0.9854437392968669
# Quoted ABC at (bid:97.83, ask:97.82, price:97.82499999999999)
# ...
# Quoted DEF at (bid:98.63, ask:98.98, price:98.805)
# Ratio 0.993978037548707
# Quoted ABC at (bid:98.6, ask:97.82, price:98.21)
# Quoted DEF at (bid:98.63, ask:98.98, price:98.805)
# Ratio 0.993978037548707
# Quoted ABC at (bid:98.6, ask:97.82, price:98.21)
# Quoted DEF at (bid:98.63, ask:98.98, price:98.805)
# Ratio 0.993978037548707
# Quoted ABC at (bid:98.6, ask:97.82, price:98.21)
# Quoted DEF at (bid:98.63, ask:98.98, price:98.805)
# Ratio 0.993978037548707
# Quoted ABC at (bid:98.6, ask:97.82, price:98.21)
# Quoted DEF at (bid:98.63, ask:98.98, price:98.805)
# Ratio 0.993978037548707
# Quoted ABC at (bid:98.6, ask:97.82, price:98.21)
# Quoted DEF at (bid:98.63, ask:98.98, price:98.805)
# Ratio 0.993978037548707
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.72, ask:98.98, price:98.85)
# Ratio 1.005209914011128
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.72, ask:98.98, price:98.85)
# Ratio 1.005209914011128
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:98.98, price:98.86)
# Ratio 1.0051082338660733
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:98.98, price:98.86)
# Ratio 1.0051082338660733
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:98.98, price:98.86)
# Ratio 1.0051082338660733
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:98.98, price:98.86)
# Ratio 1.0051082338660733
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:98.98, price:98.86)
# Ratio 1.0051082338660733
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:98.98, price:98.86)
# Ratio 1.0051082338660733
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:98.98, price:98.86)
# Ratio 1.0051082338660733
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0180318631217664
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0180318631217664
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0180318631217664
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0180318631217664
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0180318631217664
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0180318631217664
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0180318631217664
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0180318631217664
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0180318631217664
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0180318631217664
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0180318631217664
# Quoted ABC at (bid:99.1, ask:99.63, price:99.365)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0180318631217664
# Quoted ABC at (bid:98.6, ask:99.63, price:99.115)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0154705189283337
# Quoted ABC at (bid:98.6, ask:99.63, price:99.115)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0154705189283337
# Quoted ABC at (bid:98.6, ask:99.63, price:99.115)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0154705189283337
# Quoted ABC at (bid:98.6, ask:99.63, price:99.115)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0154705189283337
# Quoted ABC at (bid:98.6, ask:99.63, price:99.115)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0154705189283337
# Quoted ABC at (bid:98.6, ask:99.63, price:99.115)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0154705189283337
# Quoted ABC at (bid:98.6, ask:99.63, price:99.115)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0154705189283337
# Quoted ABC at (bid:98.6, ask:99.63, price:99.115)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0154705189283337
# Quoted ABC at (bid:98.6, ask:99.63, price:99.115)
# Quoted DEF at (bid:98.74, ask:96.47, price:97.60499999999999)
# Ratio 1.0154705189283337
# Quoted ABC at (bid:98.6, ask:99.63, price:99.115)
# Quoted DEF at (bid:98.74, ask:98.98, price:98.86)
# Ratio 1.0025794052195023
# Quoted ABC at (bid:98.6, ask:99.63, price:99.115)
# Quoted DEF at (bid:98.93, ask:98.98, price:98.95500000000001)
# Ratio 1.0016168965691474
# Quoted ABC at (bid:98.6, ask:99.63, price:99.115)
# Quoted DEF at (bid:98.93, ask:98.98, price:98.95500000000001)
# Ratio 1.0016168965691474
# Quoted ABC at (bid:98.6, ask:99.63, price:99.115)
# Quoted DEF at (bid:98.93, ask:98.98, price:98.95500000000001)
# Ratio 1.0016168965691474
# Quoted ABC at (bid:98.6, ask:98.4, price:98.5)
# Quoted DEF at (bid:98.93, ask:98.98, price:98.95500000000001)
# Ratio 0.9954019503814864
# Quoted ABC at (bid:98.6, ask:98.4, price:98.5)
# Quoted DEF at (bid:98.93, ask:98.98, price:98.95500000000001)
# Ratio 0.9954019503814864
# Quoted ABC at (bid:98.6, ask:98.4, price:98.5)
# Quoted DEF at (bid:98.93, ask:98.98, price:98.95500000000001)
# Ratio 0.9954019503814864
# Quoted ABC at (bid:98.21, ask:98.4, price:98.305)
# Quoted DEF at (bid:98.93, ask:98.98, price:98.95500000000001)
# Ratio 0.9934313576878379
# Quoted ABC at (bid:98.21, ask:98.4, price:98.305)
# Quoted DEF at (bid:98.93, ask:98.98, price:98.95500000000001)
# Ratio 0.9934313576878379
# Quoted ABC at (bid:98.21, ask:98.4, price:98.305)
# Quoted DEF at (bid:98.74, ask:97.02, price:97.88)
# Ratio 1.0043420514916226
# Quoted ABC at (bid:98.21, ask:98.4, price:98.305)
# Quoted DEF at (bid:98.74, ask:97.02, price:97.88)
# Ratio 1.0043420514916226
# Quoted ABC at (bid:98.21, ask:98.4, price:98.305)
# Quoted DEF at (bid:97.92, ask:97.28, price:97.6)
# Ratio 1.007223360655738
# Quoted ABC at (bid:98.21, ask:98.4, price:98.305)
# Quoted DEF at (bid:97.91, ask:97.75, price:97.83)
# Ratio 1.004855361341102
# Quoted ABC at (bid:98.21, ask:98.4, price:98.305)
# Quoted DEF at (bid:97.41, ask:97.75, price:97.58)
# Ratio 1.0074298011887683
# Quoted ABC at (bid:98.21, ask:98.4, price:98.305)
# Quoted DEF at (bid:97.41, ask:97.75, price:97.58)
# Ratio 1.0074298011887683
# Quoted ABC at (bid:98.21, ask:98.35, price:98.28)
# Quoted DEF at (bid:97.15, ask:97.28, price:97.215)
# Ratio 1.0109550995216787
# Quoted ABC at (bid:98.21, ask:98.35, price:98.28)
# Quoted DEF at (bid:97.15, ask:97.28, price:97.215)
# Ratio 1.0109550995216787
# Quoted ABC at (bid:98.21, ask:98.35, price:98.28)
# Quoted DEF at (bid:97.15, ask:97.28, price:97.215)
# Ratio 1.0109550995216787
# Quoted ABC at (bid:98.21, ask:98.35, price:98.28)
# Quoted DEF at (bid:97.15, ask:97.28, price:97.215)
# Ratio 1.0109550995216787
# Quoted ABC at (bid:98.21, ask:97.71, price:97.96)
# Quoted DEF at (bid:97.15, ask:97.28, price:97.215)
# Ratio 1.007663426425963
# Quoted ABC at (bid:97.41, ask:97.71, price:97.56)
# Quoted DEF at (bid:97.15, ask:97.28, price:97.215)
# Ratio 1.0035488350563184
# Quoted ABC at (bid:95.57, ask:95.79, price:95.68)
# Quoted DEF at (bid:97.15, ask:97.28, price:97.215)
# Ratio 0.9842102556189889
# Quoted ABC at (bid:95.57, ask:95.79, price:95.68)
# Quoted DEF at (bid:97.15, ask:97.28, price:97.215)
# Ratio 0.9842102556189889
# Quoted ABC at (bid:95.13, ask:93.6, price:94.365)
# Quoted DEF at (bid:95.28, ask:97.28, price:96.28)
# Ratio 0.9801100955546322
# Quoted ABC at (bid:95.13, ask:93.6, price:94.365)
# Quoted DEF at (bid:95.28, ask:97.28, price:96.28)
# Ratio 0.9801100955546322
# Quoted ABC at (bid:94.57, ask:93.6, price:94.085)
# Quoted DEF at (bid:95.28, ask:97.28, price:96.28)
# Ratio 0.9772019110926464
# Quoted ABC at (bid:94.57, ask:93.6, price:94.085)
# Quoted DEF at (bid:95.28, ask:97.28, price:96.28)
# Ratio 0.9772019110926464
# Quoted ABC at (bid:92.96, ask:93.6, price:93.28)
# Quoted DEF at (bid:95.28, ask:97.28, price:96.28)
# Ratio 0.9688408807644371
# Quoted ABC at (bid:92.96, ask:93.6, price:93.28)
# Quoted DEF at (bid:95.28, ask:97.28, price:96.28)
# Ratio 0.9688408807644371
# Quoted ABC at (bid:92.96, ask:93.6, price:93.28)
# Quoted DEF at (bid:95.28, ask:97.28, price:96.28)
# Ratio 0.9688408807644371
# Quoted ABC at (bid:92.96, ask:93.6, price:93.28)
# Quoted DEF at (bid:95.28, ask:97.28, price:96.28)
# Ratio 0.9688408807644371
# Quoted ABC at (bid:92.96, ask:93.6, price:93.28)
# Quoted DEF at (bid:95.28, ask:96.7, price:95.99000000000001)
# Ratio 0.9717678924888008
# Quoted ABC at (bid:92.96, ask:93.6, price:93.28)
# Quoted DEF at (bid:95.28, ask:96.7, price:95.99000000000001)
# Ratio 0.9717678924888008
# Quoted ABC at (bid:92.96, ask:93.6, price:93.28)
# Quoted DEF at (bid:95.28, ask:96.7, price:95.99000000000001)
# Ratio 0.9717678924888008
# Quoted ABC at (bid:92.96, ask:93.6, price:93.28)
# Quoted DEF at (bid:95.28, ask:96.7, price:95.99000000000001)
# Ratio 0.9717678924888008
# Quoted ABC at (bid:92.96, ask:93.6, price:93.28)
# Quoted DEF at (bid:95.28, ask:96.7, price:95.99000000000001)
# Ratio 0.9717678924888008
# Quoted ABC at (bid:92.96, ask:93.6, price:93.28)
# Quoted DEF at (bid:95.28, ask:95.9, price:95.59)
# Ratio 0.9758342922899884
# Quoted ABC at (bid:92.96, ask:93.6, price:93.28)
# Quoted DEF at (bid:95.28, ask:95.9, price:95.59)
# Ratio 0.9758342922899884
# Quoted ABC at (bid:92.96, ask:93.6, price:93.28)
# Quoted DEF at (bid:95.28, ask:95.9, price:95.59)
# Ratio 0.9758342922899884
# Quoted ABC at (bid:92.96, ask:93.6, price:93.28)
# Quoted DEF at (bid:93.01, ask:94.04, price:93.525)
# Ratio 0.997380379577653
# Quoted ABC at (bid:92.96, ask:94.35, price:93.655)
# Quoted DEF at (bid:93.01, ask:94.04, price:93.525)
# Ratio 1.001390002673082
# Quoted ABC at (bid:92.96, ask:94.35, price:93.655)
# Quoted DEF at (bid:93.01, ask:94.04, price:93.525)
# Ratio 1.001390002673082
# Quoted ABC at (bid:92.96, ask:94.35, price:93.655)
# Quoted DEF at (bid:93.01, ask:93.05, price:93.03)
# Ratio 1.006718262925938
# Quoted ABC at (bid:92.96, ask:93.08, price:93.02)
# Quoted DEF at (bid:93.01, ask:93.05, price:93.03)
# Ratio 0.999892507793185
# Quoted ABC at (bid:92.96, ask:93.08, price:93.02)
# Quoted DEF at (bid:93.01, ask:93.05, price:93.03)
# Ratio 0.999892507793185
# Quoted ABC at (bid:92.96, ask:93.08, price:93.02)
# Quoted DEF at (bid:93.01, ask:93.05, price:93.03)
# Ratio 0.999892507793185
# Quoted ABC at (bid:92.96, ask:92.36, price:92.66)
# Quoted DEF at (bid:93.01, ask:93.05, price:93.03)
# Ratio 0.9960227883478447
# Quoted ABC at (bid:92.96, ask:92.36, price:92.66)
# Quoted DEF at (bid:93.01, ask:93.05, price:93.03)
# Ratio 0.9960227883478447
# Quoted ABC at (bid:92.96, ask:92.36, price:92.66)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.0267036011080333
# Quoted ABC at (bid:92.96, ask:92.36, price:92.66)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.0267036011080333
# Quoted ABC at (bid:92.6, ask:92.36, price:92.47999999999999)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.0247091412742382
# Quoted ABC at (bid:92.6, ask:92.36, price:92.47999999999999)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.0247091412742382
# Quoted ABC at (bid:92.6, ask:92.36, price:92.47999999999999)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.0247091412742382
# Quoted ABC at (bid:92.6, ask:92.36, price:92.47999999999999)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.0247091412742382
# Quoted ABC at (bid:92.6, ask:92.36, price:92.47999999999999)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.0247091412742382
# Quoted ABC at (bid:92.6, ask:92.36, price:92.47999999999999)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.0247091412742382
# Quoted ABC at (bid:92.6, ask:92.36, price:92.47999999999999)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.0247091412742382
# Quoted ABC at (bid:92.6, ask:92.36, price:92.47999999999999)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.0247091412742382
# Quoted ABC at (bid:92.56, ask:92.36, price:92.46000000000001)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.024487534626039
# Quoted ABC at (bid:92.56, ask:92.36, price:92.46000000000001)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.024487534626039
# Quoted ABC at (bid:92.56, ask:92.36, price:92.46000000000001)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.024487534626039
# Quoted ABC at (bid:92.56, ask:92.36, price:92.46000000000001)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.024487534626039
# Quoted ABC at (bid:92.56, ask:92.36, price:92.46000000000001)
# Quoted DEF at (bid:90.8, ask:89.7, price:90.25)
# Ratio 1.024487534626039
# Quoted ABC at (bid:90.88, ask:92.11, price:91.495)
# Quoted DEF at (bid:90.8, ask:88.84, price:89.82)
# Ratio 1.018648407926965
# Quoted ABC at (bid:90.88, ask:92.11, price:91.495)
# Quoted DEF at (bid:90.8, ask:88.84, price:89.82)
# Ratio 1.018648407926965
# Quoted ABC at (bid:90.88, ask:91.92, price:91.4)
# Quoted DEF at (bid:90.8, ask:88.84, price:89.82)
# Ratio 1.017590737029615
# Quoted ABC at (bid:90.88, ask:91.92, price:91.4)
# Quoted DEF at (bid:90.8, ask:88.84, price:89.82)
# Ratio 1.017590737029615
# Quoted ABC at (bid:90.88, ask:91.92, price:91.4)
# Quoted DEF at (bid:89.63, ask:89.7, price:89.66499999999999)
# Ratio 1.0193498020409302
# Quoted ABC at (bid:90.88, ask:91.92, price:91.4)
# Quoted DEF at (bid:89.29, ask:89.7, price:89.495)
# Ratio 1.021286105369015
# Quoted ABC at (bid:90.88, ask:91.92, price:91.4)
# Quoted DEF at (bid:89.29, ask:89.7, price:89.495)
# Ratio 1.021286105369015
# Quoted ABC at (bid:88.83, ask:90.18, price:89.505)
# Quoted DEF at (bid:89.29, ask:89.27, price:89.28)
# Ratio 1.0025201612903225
# Quoted ABC at (bid:88.83, ask:90.18, price:89.505)
# Quoted DEF at (bid:89.29, ask:89.27, price:89.28)
# Ratio 1.0025201612903225
# Quoted ABC at (bid:88.83, ask:89.31, price:89.07)
# Quoted DEF at (bid:89.29, ask:89.27, price:89.28)
# Ratio 0.9976478494623655
# Quoted ABC at (bid:88.83, ask:89.31, price:89.07)
# Quoted DEF at (bid:89.29, ask:89.27, price:89.28)
# Ratio 0.9976478494623655
# Quoted ABC at (bid:88.83, ask:86.41, price:87.62)
# Quoted DEF at (bid:88.7, ask:89.27, price:88.985)
# Ratio 0.9846603360116875
# Quoted ABC at (bid:88.83, ask:86.41, price:87.62)
# Quoted DEF at (bid:88.7, ask:89.27, price:88.985)
# Ratio 0.9846603360116875
# Quoted ABC at (bid:88.83, ask:86.41, price:87.62)
# Quoted DEF at (bid:88.7, ask:89.27, price:88.985)
# Ratio 0.9846603360116875
# Quoted ABC at (bid:88.83, ask:86.41, price:87.62)
# Quoted DEF at (bid:88.7, ask:89.27, price:88.985)
# Ratio 0.9846603360116875
# Quoted ABC at (bid:88.46, ask:86.41, price:87.435)
# Quoted DEF at (bid:88.7, ask:88.84, price:88.77000000000001)
# Ratio 0.9849611355187563
# Quoted ABC at (bid:88.46, ask:86.41, price:87.435)
# Quoted DEF at (bid:88.7, ask:88.84, price:88.77000000000001)
# Ratio 0.9849611355187563
# Quoted ABC at (bid:86.94, ask:87.13, price:87.035)
# Quoted DEF at (bid:87.96, ask:88.09, price:88.025)
# Ratio 0.988753195115024
# Quoted ABC at (bid:86.94, ask:87.13, price:87.035)
# Quoted DEF at (bid:87.96, ask:88.09, price:88.025)
# Ratio 0.988753195115024
# Quoted ABC at (bid:86.94, ask:87.13, price:87.035)
# Quoted DEF at (bid:87.96, ask:88.09, price:88.025)
# Ratio 0.988753195115024
# Quoted ABC at (bid:86.86, ask:87.13, price:86.995)
# Quoted DEF at (bid:87.96, ask:88.09, price:88.025)
# Ratio 0.9882987787560352
# Quoted ABC at (bid:85.28, ask:86.41, price:85.845)
# Quoted DEF at (bid:87.96, ask:88.09, price:88.025)
# Ratio 0.9752343084351036
# Quoted ABC at (bid:85.28, ask:83.98, price:84.63)
# Quoted DEF at (bid:87.96, ask:88.09, price:88.025)
# Ratio 0.961431411530815
# Quoted ABC at (bid:85.28, ask:83.98, price:84.63)
# Quoted DEF at (bid:87.96, ask:88.09, price:88.025)
# Ratio 0.961431411530815
# Quoted ABC at (bid:84.33, ask:83.98, price:84.155)
# Quoted DEF at (bid:87.96, ask:88.09, price:88.025)
# Ratio 0.9560352172678216
